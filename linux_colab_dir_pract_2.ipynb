# %%
# 1. Show command for present working direcotry
# !pwd
# Out:
# /content

# %%
# 2.command to Create a directory
# !mkdir /content/test_dir

# %%
# 3. command to create 3 in test_directory files
# !touch /content/test_dir/test_1.txt

# %%
# !touch /content/test_dir/test_2.txt

# %%
# !touch /content/test_dir/test_3.txt

# %%
# 4. check the content of linux_exercise test_dir directory

# %%
# !cd /content/test_dir/  && ls
# Out:
# test_1.txt  test_2.txt	test_3.txt

# %%
# 5. Use the find command to locate text files:
# !find /content/test_dir/  "*.txt"
# Out:
# /content/test_dir/
# /content/test_dir/test_1.txt
# /content/test_dir/test_3.txt
# /content/test_dir/test_2.txt
# find: ‘*.txt’: No such file or directory

# %%
# 6. command helps count number in all txt files it shows word count, lines and character counts :
# !wc /content/test_dir/book.txt
# Out:
#    902  46075 264875 /content/test_dir/book.txt

# %%
# 7. Write Hello in all test files

with open ('/content/test_dir/test_1.txt', 'w') as f:
  f.write ("Hello world am Dayo")

# %%
# 8. search for the word Hello in files
# !grep 'Hello' /content/test_dir/test_1.txt
# Out:
# Hello world am Dayo

# %%
# 9. Moving files into folder
# !mv /content/sample_data/california_housing_test.csv /content/test_dir

# %%
#10. Create a symbolic link for file1 in folder:
# !ln -s /content/sample_data/mnist_test.csv /content/test_dir/link_to_file.txt

# %%
# 11. Remove an entire directory

# %%
# !rm -rf /content/test_dir
